# %% [markdown]
# 1.	Read the data set and replace dashes with 0 to make sure you can perform arithmetic operations on the data.

# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as pyt

# %%
df=pd.read_csv('Laliga.csv');
print(df)
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1          Real Madrid       86   4385        2762     1647        552
# 1     2            Barcelona       86   4262        2762     1581        573
# 2     3      Atletico Madrid       80   3442        2614     1241        598
# 3     4             Valencia       82   3386        2664     1187        616
# 4     5      Athletic Bilbao       86   3368        2762     1209        633
# 5     6              Sevilla       73   2819        2408      990        531
# 6     7             Espanyol       82   2792        2626      948        608
# 7     8        Real Sociedad       70   2573        2302      864        577
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# ...

# %%
df=df.replace('-',0)

# %% [markdown]
# 2.	Print all the teams which have started playing between 1930-1980

# %%
##df['Debut'].astype(object).astype(int)
comp=(df['Debut']>='1930') & (df['Debut']<='1980')
df[comp]
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 3     4             Valencia       82   3386        2664     1187        616
# 5     6              Sevilla       73   2819        2408      990        531
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# 11   12           Celta Vigo       51   1789        1698      586        389
# 12   13           Valladolid       42   1471        1466      463        384
# 14   15       Sporting Gijon       43   1389        1458      471        358
# 15   16              Osasuna       37   1351        1318      426        327
# 16   17               Malaga       36   1314        1255      390        330
# 17   18               Oviedo       38   1174        1192      408        292
# ...

# %% [markdown]
# 3.	Print the list of teams which came Top 5 in terms of points (2.5 points)

# %%
df['Points']=df['Points'].astype(float)
print(df.sort_values('Points',ascending=False).head(5))
##df.sort_values(by='Points',ascending=False)
# Out:
#    Pos             Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86  4385.0        2762     1647        552
# 1    2        Barcelona       86  4262.0        2762     1581        573
# 2    3  Atletico Madrid       80  3442.0        2614     1241        598
# 3    4         Valencia       82  3386.0        2664     1187        616
# 4    5  Athletic Bilbao       86  3368.0        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth Sixth  \
# 0       563     5947         3140       33        23     8      8     3     4
# 1       608     5900         3114       25        25    12     12     4     6
# 2       775     4534         3309       10         8    16      9     7     6
# 3       861     4398         3469        6         6    10     11    10     7
# 4       920     4631         3700        8         7    10      5     8    10
#
#     T    Debut Since/LastApp  BestPosition
# ...

# %% [markdown]
# 4.	Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)

# %%
df['GoalsFor']=df['GoalsFor'].astype(int)
df['GoalsAgainst']=df['GoalsAgainst'].astype(int)

df['GoalDiff']=df['GoalsFor']-df['GoalsAgainst']

## Function for Goal Difference Count
def Goal_diff_count():
    df['GoalDiff']=df['GoalsFor']-df['GoalsAgainst']
    print(df.loc[:,['Team','GoalDiff']])
    ##Team with Maximum difference
    print(df.loc[:,['Team','GoalDiff']].sort_values(by='GoalDiff',ascending=False).head(1))
    ##Team with Minimum difference
    print(df.loc[:,['Team','GoalDiff']].sort_values(by='GoalDiff',ascending=False).tail(1))
    
##df.info()
print(Goal_diff_count())
##print(df)
# Out:
#                    Team  GoalDiff
# 0           Real Madrid      2807
# 1             Barcelona      2786
# 2       Atletico Madrid      1225
# 3              Valencia       929
# 4       Athletic Bilbao       931
# 5               Sevilla       307
# 6              Espanyol      -280
# 7         Real Sociedad        -2
# 8              Zaragoza      -164
# 9            Real Betis      -333
# 10  Deportivo La Coruna      -136
# 11           Celta Vigo      -346
# 12           Valladolid      -413
# 13     Racing Santander      -525
# 14       Sporting Gijon      -399
# 15              Osasuna      -334
# 16               Malaga      -342
# 17               Oviedo      -309
# 18             Mallorca      -189
# 19           Las Palmas      -399
# 20           Villarreal       103
# 21              Granada      -338
# 22       Rayo Vallecano      -328
# 23                Elche      -272
# 24               Getafe      -113
# 25             Hercules      -334
# ...

# %% [markdown]
# 1.	Create a new column with the name “Winning Percent” and append it to the data set (5 points)
# Percentage of Winning = (GamesWon / GamesPlayed)*100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 20 columns):
# Pos              61 non-null int64
# Team             61 non-null object
# Seasons          61 non-null int64
# Points           61 non-null float64
# GamesPlayed      61 non-null object
# GamesWon         61 non-null object
# GamesDrawn       61 non-null object
# GamesLost        61 non-null object
# GoalsFor         61 non-null object
# GoalsAgainst     61 non-null object
# Champion         61 non-null object
# Runner-up        61 non-null object
# Third            61 non-null object
# Fourth           61 non-null object
# Fifth            61 non-null object
# Sixth            61 non-null object
# T                61 non-null object
# Debut            61 non-null object
# Since/LastApp    61 non-null object
# BestPosition     61 non-null int64
# dtypes: float64(1), int64(3), object(16)
# memory usage: 9.6+ KB

# %%
df['GamesWon']=df['GamesWon'].astype(int)
df['GamesPlayed']=df['GamesPlayed'].astype(int)
df['Winning Percent']=(df['GamesWon']/df['GamesPlayed'])*100

##If there are any numerical error, replace it with 0%

df['Winning Percent']=df['Winning Percent'].fillna(0)
print(df['Winning Percent'])

print(df.sort_values(by='Winning Percent',ascending=False).head(5))
##df.drop('Winninn Percent',axis=0,inplace=True)
# Out:
# 0     59.630702
# 1     57.241130
# 2     47.475134
# 3     44.557057
# 4     43.772629
# 5     41.112957
# 6     36.100533
# 7     37.532580
# 8     35.146022
# 9     35.069444
# 10    36.797386
# 11    34.511190
# 12    31.582538
# 13    31.722689
# 14    32.304527
# 15    32.321700
# 16    31.075697
# 17    34.228188
# 18    33.704453
# 19    33.485401
# 20    41.176471
# 21    29.380054
# 22    28.987730
# 23    29.941003
# 24    32.236842
# 25    29.299363
# 26    31.376518
# 27    24.744027
# 28    32.894737
# 29    28.109453
#         ...
# 31    30.281690
# 32    23.214286
# 33    27.745665
# 34    30.838323
# 35    28.148148
# 36    27.192982
# 37    29.078014
# 38    32.500000
# 39    26.881720
# 40    28.921569
# 41    29.444444
# 42    24.342105
# 43    30.701754
# 44    33.076923
# 45    22.807018
# 46    29.310345
# 47    25.000000
# 48    23.750000
# 49    27.777778
# 50    32.222222
# 51    29.166667
# 52    25.000000
# 53    33.333333
# 54    19.117647
# ...

# %% [markdown]
# 1.	Group teams based on their “Best position” and print the sum of their points for all positions (7.5 points)

# %%
##df['Champion']=df['Champion'].astype(int)
##df['Runner-up']=df['Runner-up'].astype(int)
##df['Third']=df['Third'].astype(int)
##df['Fourth']=df['Fourth'].astype(int)
##df['Fifth']=df['Fifth'].astype(int)
##df['Sixth']=df['Sixth'].astype(int)
##df['T']=df['T'].astype(int)

##agg({"Champion": "sum",'Runner-up':"sum"})
##df_BestPosition=df.groupby('BestPosition').sum()[['Champion','Runner-up','Third','Fourth','Fifth','Sixth','T']]
##print(df_BestPosition)
##df['Total']

df.groupby('BestPosition',as_index=False).agg({"Points":"sum"})
# Out:
#     BestPosition   Points
# 0              1  27933.0
# 1              2   6904.0
# 2              3   5221.0
# 3              4   6563.0
# 4              5   1884.0
# 5              6   2113.0
# 6              7   1186.0
# 7              8   1134.0
# 8              9     96.0
# 9             10    450.0
# 10            11    445.0
# 11            12    511.0
# 12            14     71.0
# 13            15     14.0
# 14            16     81.0
# 15            17    266.0
# 16            19     81.0
# 17            20     34.0
